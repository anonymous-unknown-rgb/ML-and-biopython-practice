# %%
import pandas as pd
import numpy as np
from sklearn.datasets import load_breast_cancer
from sklearn.model_selection import train_test_split

# %%
data=load_breast_cancer()

df=pd.DataFrame(data.data, columns=data.feature_names)
df["target"]=data.target
df.head()
# Out:
#    mean radius  mean texture  mean perimeter  mean area  mean smoothness  \
# 0        17.99         10.38          122.80     1001.0          0.11840
# 1        20.57         17.77          132.90     1326.0          0.08474
# 2        19.69         21.25          130.00     1203.0          0.10960
# 3        11.42         20.38           77.58      386.1          0.14250
# 4        20.29         14.34          135.10     1297.0          0.10030
#
#    mean compactness  mean concavity  mean concave points  mean symmetry  \
# 0           0.27760          0.3001              0.14710         0.2419
# 1           0.07864          0.0869              0.07017         0.1812
# 2           0.15990          0.1974              0.12790         0.2069
# 3           0.28390          0.2414              0.10520         0.2597
# 4           0.13280          0.1980              0.10430         0.1809
#
#    mean fractal dimension  ...  worst texture  worst perimeter  worst area  \
# 0                 0.07871  ...          17.33           184.60      2019.0
# 1                 0.05667  ...          23.41           158.80      1956.0
# 2                 0.05999  ...          25.53           152.50      1709.0
# 3                 0.09744  ...          26.50            98.87       567.7
# 4                 0.05883  ...          16.67           152.20      1575.0
#
#    worst smoothness  worst compactness  worst concavity  worst concave points  \
# 0            0.1622             0.6656           0.7119                0.2654
# 1            0.1238             0.1866           0.2416                0.1860
# 2            0.1444             0.4245           0.4504                0.2430
# 3            0.2098             0.8663           0.6869                0.2575
# 4            0.1374             0.2050           0.4000                0.1625
#
#    worst symmetry  worst fractal dimension  target
# 0          0.4601                  0.11890       0
# 1          0.2750                  0.08902       0
# 2          0.3613                  0.08758       0
# 3          0.6638                  0.17300       0
# 4          0.2364                  0.07678       0
#
# [5 rows x 31 columns]

# %%
x=df.drop('target', axis=1)
y=df["target"]
x_train,x_test,y_train,y_test=train_test_split(x,y, test_size=0.2)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

model=Sequential()
model.add(Dense(16,activation='relu', input_shape=(30,)))
model.add(Dense(8,activation='relu'))
model.add(Dense(1,activation='sigmoid'))

model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

model.fit(x_train, y_train, epochs=20, batch_size=32, validation_split=0.2)
# Out:
# Epoch 1/20
# WARNING:tensorflow:From c:\Users\mules\AppData\Local\Python\pythoncore-3.11-64\Lib\site-packages\keras\src\utils\tf_utils.py:492: The name tf.ragged.RaggedTensorValue is deprecated. Please use tf.compat.v1.ragged.RaggedTensorValue instead.
#
# WARNING:tensorflow:From c:\Users\mules\AppData\Local\Python\pythoncore-3.11-64\Lib\site-packages\keras\src\engine\base_layer_utils.py:384: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.
#
# 12/12 [==============================] - 1s 13ms/step - loss: 11.2958 - accuracy: 0.3874 - val_loss: 8.2727 - val_accuracy: 0.2857
# Epoch 2/20
# 12/12 [==============================] - 0s 3ms/step - loss: 3.9350 - accuracy: 0.4505 - val_loss: 0.9245 - val_accuracy: 0.7363
# Epoch 3/20
# 12/12 [==============================] - 0s 4ms/step - loss: 0.5666 - accuracy: 0.8379 - val_loss: 0.4320 - val_accuracy: 0.9451
# Epoch 4/20
# 12/12 [==============================] - 0s 3ms/step - loss: 0.8521 - accuracy: 0.8736 - val_loss: 0.3470 - val_accuracy: 0.9341
# Epoch 5/20
# 12/12 [==============================] - 0s 3ms/step - loss: 0.5691 - accuracy: 0.8681 - val_loss: 0.3492 - val_accuracy: 0.8791
# Epoch 6/20
# 12/12 [==============================] - 0s 3ms/step - loss: 0.4837 - accuracy: 0.8434 - val_loss: 0.3553 - val_accuracy: 0.8681
# Epoch 7/20
# 12/12 [==============================] - 0s 3ms/step - loss: 0.4645 - accuracy: 0.8571 - val_loss: 0.3117 - val_accuracy: 0.9231
# Epoch 8/20
# 12/12 [==============================] - 0s 3ms/step - loss: 0.4492 - accuracy: 0.8626 - val_loss: 0.3147 - val_accuracy: 0.9011
# Epoch 9/20
# 12/12 [==============================] - 0s 3ms/step - loss: 0.4482 - accuracy: 0.8709 - val_loss: 0.2858 - val_accuracy: 0.9231
# Epoch 10/20
# 12/12 [==============================] - 0s 3ms/step - loss: 0.4343 - accuracy: 0.8709 - val_loss: 0.2961 - val_accuracy: 0.9121
# Epoch 11/20
# 12/12 [==============================] - 0s 3ms/step - loss: 0.4317 - accuracy: 0.8791 - val_loss: 0.2680 - val_accuracy: 0.9231
# Epoch 12/20
# 12/12 [==============================] - 0s 3ms/step - loss: 0.4119 - accuracy: 0.8819 - val_loss: 0.2851 - val_accuracy: 0.9121
# Epoch 13/20
# 12/12 [==============================] - 0s 3ms/step - loss: 0.4008 - accuracy: 0.8791 - val_loss: 0.2683 - val_accuracy: 0.9231
# Epoch 14/20
# 12/12 [==============================] - 0s 3ms/step - loss: 0.4007 - accuracy: 0.8846 - val_loss: 0.2614 - val_accuracy: 0.9231
# Epoch 15/20
# 12/12 [==============================] - 0s 3ms/step - loss: 0.3909 - accuracy: 0.8846 - val_loss: 0.2772 - val_accuracy: 0.9121
# Epoch 16/20
# 12/12 [==============================] - 0s 3ms/step - loss: 0.3844 - accuracy: 0.8819 - val_loss: 0.2849 - val_accuracy: 0.9121
# Epoch 17/20
# 12/12 [==============================] - 0s 3ms/step - loss: 0.3796 - accuracy: 0.8764 - val_loss: 0.2632 - val_accuracy: 0.9231
# Epoch 18/20
# 12/12 [==============================] - 0s 3ms/step - loss: 0.3736 - accuracy: 0.8846 - val_loss: 0.2836 - val_accuracy: 0.9121
# Epoch 19/20
# 12/12 [==============================] - 0s 3ms/step - loss: 0.3652 - accuracy: 0.8846 - val_loss: 0.2614 - val_accuracy: 0.9231
# Epoch 20/20
# 12/12 [==============================] - 0s 3ms/step - loss: 0.3686 - accuracy: 0.8901 - val_loss: 0.2514 - val_accuracy: 0.9231

# %%
loss, accuracy = model.evaluate(x_test, y_test)
print(f"Test Accuracy: {accuracy * 100:.2f}%")
# Out:
# 4/4 [==============================] - 0s 2ms/step - loss: 0.1999 - accuracy: 0.9561
# Test Accuracy: 95.61%
